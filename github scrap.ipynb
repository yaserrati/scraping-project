# %% [markdown]
# # <center> Scraping GitHub </center>

# %% [markdown]
# ### Importation

# %%
import requests
import csv
import pandas as pd
from datetime import datetime, timedelta
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %% [markdown]
# ### GitHub API base URL

# %%
base_url = 'https://api.github.com'

# %% [markdown]
# ### My GitHub username

# %%
username = 'yaserrati'

# %% [markdown]
# ### GitHub access token

# %%
access_token = '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'

# %% [markdown]
# ### Number of repositories per day

# %%
repositories_per_day = 750

# %% [markdown]
# ### Number of days to scrape

# %%
days_to_scrape = 365

# %% [markdown]
# ### Calculer les dates de début et de fin du scraping

# %%
end_date = datetime.now().date()
start_date = end_date - timedelta(days=days_to_scrape)

# %% [markdown]
# ### Initialiser la liste des référentiels

# %%
repositories = []

# %% [markdown]
# ### Mécanisme de nouvelle tentative pour API requests

# %%
retry_strategy = Retry(
    total=3,
    backoff_factor=0.5,
    status_forcelist=[429, ², 502, 503, 504],
    method_whitelist=["GET"],
)
adapter = HTTPAdapter(max_retries=retry_strategy)
http = requests.Session()
http.mount("https://", adapter)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_61576\1250331195.py:1: DeprecationWarning: Using 'method_whitelist' with Retry is deprecated and will be removed in v2.0. Use 'allowed_methods' instead
#   retry_strategy = Retry(

# %% [markdown]
# ### Itérer chaque jour

# %%
for day in range(days_to_scrape):
    current_date = start_date + timedelta(days=day)
    formatted_date = current_date.strftime('%Y-%m-%d')

    # Fetch repositories using pagination
    page = 1
    while len(repositories) < repositories_per_day * (day + 1):
        # Create the API URL to fetch repositories created on the current day and specific page
        url = f'{base_url}/search/repositories?q=created:{formatted_date}&sort=stars&order=desc&per_page=100&page={page}'

        # Make the API request with retry logic
        headers = {'Authorization': f'token {access_token}'} if access_token else {}
        response = http.get(url, headers=headers)
        data = response.json()

        if 'items' in data:
            # Extract repository information from the response
            items = data['items']
            sorted_items = sorted(items, key=lambda item: item['stargazers_count'], reverse=True)

            for item in sorted_items[:repositories_per_day]:
                repository = {
                    'name': item['name'],
                    'url': item['html_url'],
                    'description': item['description'],
                    'stars': item['stargazers_count'],
                    'created_at': item['created_at'],
                    'language': item.get('language', ''),  # Use dict.get() with a default value
                    'forks': item['forks'],
                    'watchers': item['watchers'],
                    'open_issues': item['open_issues'],
                    'owner': item['owner']['login']
                }

                repositories.append(repository)

        page += 1

        if 'next' not in response.links:
            break

# %% [markdown]
# ### Output CSV file name

# %%
output_file = 'repositories_data.csv'

# %% [markdown]
# ### Write the repository data to a CSV file

# %%
with open(output_file, 'w', newline='', encoding='utf-8') as file:
    fieldnames = ['name', 'url', 'description', 'stars', 'created_at', 'language','forks','watchers','open_issues','owner']
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(repositories)

print('Repositories scraped and saved successfully!')
# Out:
# Repositories scraped and saved successfully!

# %% [markdown]
# ### Save to Excel file

# %%
# Convert extracted data to a DataFrame
df = pd.DataFrame(repositories)

# Define the file paths
excel_file_path = 'repositories_data.xlsx'

# Write the data to the Excel file
df.to_excel(excel_file_path, index=False)

# %% [markdown]
# ### Read data

# %%
df = pd.read_csv('repositories_data.csv')
df
# Out:
#                         name
# 0                  notepad--  \
# 1       pocket-casts-android
# 2             nvim-basic-ide
# 3                  sismo-hub
# 4                    Antenna
# ...                      ...
# 273791           preparation
# 273792                  1254
# 273793                    vm
# 273794            drugmanage
# 273795       mainnetironfish
#
#                                                       url
# 0                      https://github.com/cxasm/notepad--  \
# 1       https://github.com/Automattic/pocket-casts-and...
# 2              https://github.com/LunarVim/nvim-basic-ide
# 3                 https://github.com/sismo-core/sismo-hub
# 4                         https://github.com/wuba/Antenna
# ...                                                   ...
# 273791             https://github.com/sxa4680/preparation
# 273792                    https://github.com/tomenli/1254
# 273793               https://github.com/wayneundefined/vm
# 273794         https://github.com/Derunter5958/drugmanage
# 273795  https://github.com/mainnetironfish/mainnetiron...
#
#                                               description  stars
# 0         一个支持windows/linux/mac的文本编辑器，目标是做中国人自己的编辑器，来自中国。   2877  \
# 1                                  Pocket Casts Android 🎧   2243
# 2       🪨 This is my attempt at a basic stable startin...   1653
# 3                                                     NaN    890
# 4       Antenna是58同城安全团队打造的一款辅助安全从业人员验证网络中多种漏洞是否存在以及可利...    675
# ...                                                   ...    ...
# 273791  Proper preparation solves 80 percent of life’s...      2
# 273792                                               1254      2
# 273793                                                NaN      2
# 273794                                            管理系统的代码      2
# 273795                Config files for my GitHub profile.      2
#
#                   created_at    language  forks  watchers  open_issues
# 0       2022-06-15T02:50:15Z         C++    114      2877          111  \
# 1       2022-06-15T12:41:42Z      Kotlin    165      2243          252
# 2       2022-06-15T23:06:53Z         Lua    437      1653            1
# 3       2022-06-15T16:44:53Z  TypeScript    181       890            7
# 4       2022-06-15T06:42:25Z  JavaScript     72       675            3
# ...                      ...         ...    ...       ...          ...
# 273791  2023-06-14T04:18:45Z         NaN      2         2            0
# 273792  2023-06-14T04:54:55Z         NaN      0         2            0
# 273793  2023-06-14T06:44:18Z         NaN      1         2            0
# 273794  2023-06-14T07:20:22Z         Vue      0         2            1
# 273795  2023-06-14T07:34:35Z         NaN      1         2            0
#
#                   owner
# 0                 cxasm
# 1            Automattic
# 2              LunarVim
# 3            sismo-core
# 4                  wuba
# ...                 ...
# 273791          sxa4680
# 273792          tomenli
# 273793   wayneundefined
# 273794     Derunter5958
# 273795  mainnetironfish
#
# [273796 rows x 10 columns]

# %% [markdown]
# ### Drop les doublons

# %%
df.drop_duplicates()
# Out:
#                         name
# 0                  notepad--  \
# 1       pocket-casts-android
# 2             nvim-basic-ide
# 3                  sismo-hub
# 4                    Antenna
# ...                      ...
# 273791           preparation
# 273792                  1254
# 273793                    vm
# 273794            drugmanage
# 273795       mainnetironfish
#
#                                                       url
# 0                      https://github.com/cxasm/notepad--  \
# 1       https://github.com/Automattic/pocket-casts-and...
# 2              https://github.com/LunarVim/nvim-basic-ide
# 3                 https://github.com/sismo-core/sismo-hub
# 4                         https://github.com/wuba/Antenna
# ...                                                   ...
# 273791             https://github.com/sxa4680/preparation
# 273792                    https://github.com/tomenli/1254
# 273793               https://github.com/wayneundefined/vm
# 273794         https://github.com/Derunter5958/drugmanage
# 273795  https://github.com/mainnetironfish/mainnetiron...
#
#                                               description  stars
# 0         一个支持windows/linux/mac的文本编辑器，目标是做中国人自己的编辑器，来自中国。   2877  \
# 1                                  Pocket Casts Android 🎧   2243
# 2       🪨 This is my attempt at a basic stable startin...   1653
# 3                                                     NaN    890
# 4       Antenna是58同城安全团队打造的一款辅助安全从业人员验证网络中多种漏洞是否存在以及可利...    675
# ...                                                   ...    ...
# 273791  Proper preparation solves 80 percent of life’s...      2
# 273792                                               1254      2
# 273793                                                NaN      2
# 273794                                            管理系统的代码      2
# 273795                Config files for my GitHub profile.      2
#
#                   created_at    language  forks  watchers  open_issues
# 0       2022-06-15T02:50:15Z         C++    114      2877          111  \
# 1       2022-06-15T12:41:42Z      Kotlin    165      2243          252
# 2       2022-06-15T23:06:53Z         Lua    437      1653            1
# 3       2022-06-15T16:44:53Z  TypeScript    181       890            7
# 4       2022-06-15T06:42:25Z  JavaScript     72       675            3
# ...                      ...         ...    ...       ...          ...
# 273791  2023-06-14T04:18:45Z         NaN      2         2            0
# 273792  2023-06-14T04:54:55Z         NaN      0         2            0
# 273793  2023-06-14T06:44:18Z         NaN      1         2            0
# 273794  2023-06-14T07:20:22Z         Vue      0         2            1
# 273795  2023-06-14T07:34:35Z         NaN      1         2            0
#
#                   owner
# 0                 cxasm
# 1            Automattic
# 2              LunarVim
# 3            sismo-core
# 4                  wuba
# ...                 ...
# 273791          sxa4680
# 273792          tomenli
# 273793   wayneundefined
# 273794     Derunter5958
# 273795  mainnetironfish
#
# [272809 rows x 10 columns]

# %% [markdown]
# # <center> Fin </center>
