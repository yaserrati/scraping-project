# %%
import requests
import csv
from datetime import datetime, timedelta
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %%
# GitHub API base URL
base_url = 'https://api.github.com'

# %%
# GitHub username
username = 'yaserrati'

# %%
# GitHub access token (optional, only needed for higher rate limits)
access_token = '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'

# %%
# Number of repositories per day
repositories_per_day = 100

# %%
# Number of days to scrape
days_to_scrape = 20

# %%
# Output CSV file name
output_file = 'reposfinal.csv'

# %%
# Calculate the start and end dates for scraping
end_date = datetime.now().date()
start_date = end_date - timedelta(days=days_to_scrape)

# %%
# Initialize the repositories list
repositories = []

# %%
import requests
import csv
from datetime import datetime, timedelta
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# GitHub API base URL
base_url = 'https://api.github.com'

# GitHub username
username = 'yaserrati'

# GitHub access token (optional, only needed for higher rate limits)
access_token = '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'

# Number of repositories per day
repositories_per_day = 100

# Number of days to scrape
days_to_scrape = 20

# Output CSV file name
output_file = 'reposfinal.csv'

# Calculate the start and end dates for scraping
end_date = datetime.now().date()
start_date = end_date - timedelta(days=days_to_scrape)

# Initialize the repositories list
repositories = []

# Retry mechanism for API requests
retry_strategy = Retry(
    total=3,
    backoff_factor=0.5,
    status_forcelist=[429, 500, 502, 503, 504],
    method_whitelist=["GET"],
)
adapter = HTTPAdapter(max_retries=retry_strategy)
http = requests.Session()
http.mount("https://", adapter)

# Iterate over each day
for day in range(days_to_scrape):
    current_date = start_date + timedelta(days=day)
    formatted_date = current_date.strftime('%Y-%m-%d')

    # Fetch repositories using pagination
    page = 1
    while len(repositories) < repositories_per_day * (day + 1):
        # Create the API URL to fetch repositories created on the current day and specific page
        url = f'{base_url}/search/repositories?q=created:{formatted_date}&sort=stars&order=desc&per_page=100&page={page}'

        # Make the API request with retry logic
        headers = {'Authorization': f'token {access_token}'} if access_token else {}
        response = http.get(url, headers=headers)
        data = response.json()

        if 'items' in data:
            # Extract repository information from the response
            items = data['items']
            sorted_items = sorted(items, key=lambda item: item['stargazers_count'], reverse=True)

            for item in sorted_items[:repositories_per_day]:
                repository = {
                    'name': item['name'],
                    'url': item['html_url'],
                    'description': item['description'],
                    'stars': item['stargazers_count'],
                    'created_at': item['created_at'],
                    'language': item.get('language', '')  # Use dict.get() with a default value
                }

                repositories.append(repository)

        page += 1

        if 'next' not in response.links:
            break

# Write the repository data to a CSV file
with open(output_file, 'w', newline='', encoding='utf-8') as file:
    fieldnames = ['name', 'url', 'description', 'stars', 'created_at', 'language']
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(repositories)

print('Repositories scraped and saved successfully!')


# Define the file paths
excel_file_path = 'repositories_data1.xlsx'

# Write the data to the Excel file
df.to_excel(excel_file_path, index=False)
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_69136\1824052197.py:33: DeprecationWarning: Using 'method_whitelist' with Retry is deprecated and will be removed in v2.0. Use 'allowed_methods' instead
#   retry_strategy = Retry(
# Repositories scraped and saved successfully!

# %%
import pandas as pd
df = pd.read_csv('reposfinal.csv')
df
# Out:
#                  name                                           url
# 0             Voyager           https://github.com/MineDojo/Voyager  \
# 1          privateGPT      https://github.com/SamurAIGPT/privateGPT
# 2     prolificdreamer     https://github.com/thu-ml/prolificdreamer
# 3       LLM-ToolMaker      https://github.com/ctlllll/LLM-ToolMaker
# 4     AdGuardian-Term    https://github.com/Lissy93/AdGuardian-Term
# ...               ...                                           ...
# 1995      fpga-router    https://github.com/Centaurus99/fpga-router
# 1996      robowork-34   https://github.com/R2D2robowork/robowork-34
# 1997         Security          https://github.com/Syrusmir/Security
# 1998         python-P           https://github.com/BaraPav/python-P
# 1999     R2D2robowork  https://github.com/R2D2robowork/R2D2robowork
#
#                                             description  stars
# 0     An Open-Ended Embodied Agent with Large Langua...   3320  \
# 1     An app to interact privately with your documen...   2006
# 2     ProlificDreamer: High-Fidelity and Diverse Tex...    790
# 3                                                   NaN    741
# 4     🛡️ Terminal-based, real-time traffic monitorin...    629
# ...                                                 ...    ...
# 1995    A four-1gbe-port IPv6 router with RIPng support     10
# 1996                                                NaN     10
# 1997                                                NaN     10
# 1998                                           activity      9
# 1999                Config files for my GitHub profile.      9
#
#                 created_at          language
# 0     2023-05-25T18:20:15Z        JavaScript
# 1     2023-05-25T14:21:12Z        JavaScript
# 2     2023-05-25T13:50:00Z               NaN
# 3     2023-05-25T19:20:40Z  Jupyter Notebook
# 4     2023-05-25T12:17:23Z              Rust
# ...                    ...               ...
# 1995  2023-06-13T10:10:19Z          Assembly
# 1996  2023-06-13T14:31:25Z               NaN
# 1997  2023-06-13T18:20:26Z               NaN
# 1998  2023-06-13T12:59:00Z               NaN
# 1999  2023-06-13T14:28:11Z               NaN
#
# [2000 rows x 6 columns]

# %%
df.drop_duplicates()
# Out:
#                  name                                            url
# 0             Voyager            https://github.com/MineDojo/Voyager  \
# 1          privateGPT       https://github.com/SamurAIGPT/privateGPT
# 2     prolificdreamer      https://github.com/thu-ml/prolificdreamer
# 3       LLM-ToolMaker       https://github.com/ctlllll/LLM-ToolMaker
# 4     AdGuardian-Term     https://github.com/Lissy93/AdGuardian-Term
# ...               ...                                            ...
# 1995          elodino           https://github.com/elodino41/elodino
# 1996   CintakuUntukmu  https://github.com/HetiGendisa/CintakuUntukmu
# 1997          royatac           https://github.com/royatacak/royatac
# 1998          messhud           https://github.com/messhud51/messhud
# 1999     Tiger-qq-bot        https://github.com/wordweb/Tiger-qq-bot
#
#                                             description  stars
# 0     An Open-Ended Embodied Agent with Large Langua...   3320  \
# 1     An app to interact privately with your documen...   2005
# 2     ProlificDreamer: High-Fidelity and Diverse Tex...    789
# 3                                                   NaN    741
# 4     🛡️ Terminal-based, real-time traffic monitorin...    629
# ...                                                 ...    ...
# 1995                                                NaN     12
# 1996                                                NaN     12
# 1997                                                NaN     12
# 1998                                                NaN     12
# 1999  基于langchain-chatglm-and-tigerbot+mirai 实现的一个qq...     11
#
#                 created_at          language
# 0     2023-05-25T18:20:15Z        JavaScript
# 1     2023-05-25T14:21:12Z        JavaScript
# 2     2023-05-25T13:50:00Z               NaN
# 3     2023-05-25T19:20:40Z  Jupyter Notebook
# 4     2023-05-25T12:17:23Z              Rust
# ...                    ...               ...
# 1995  2023-06-13T17:21:05Z               NaN
# 1996  2023-06-13T12:19:45Z               NaN
# 1997  2023-06-13T17:33:29Z               NaN
# 1998  2023-06-13T17:35:11Z               NaN
# 1999  2023-06-13T09:31:32Z            Python
#
# [2000 rows x 6 columns]

# %%
df
